# %%
#2438
num = int(input())
for i in range(num):
    print('*'*(i+1))
# Out:
# 5
# *
# **
# ***
# ****
# *****

# %%
#2439
num = int(input())
for i in range(num):
    for k in range(num,-1):
        print(k)
# Out:
# 1

# %%
#2440

# %%
#2441

# %%
#2442

# %%
#2445

# %%
#2522

# %%
#2446

# %%
#10991

# %%
#10992
